# %%
import pandas as pd
import numpy as np

# %%
coordinates = pd.read_csv('world_coordinates.csv')

# %%
coordinates
# Out:
#     Code               Country   latitude  longitude
# 0     AD               Andorra  42.546245   1.601554
# 1     AE  United Arab Emirates  23.424076  53.847818
# 2     AF           Afghanistan  33.939110  67.709953
# 3     AG   Antigua and Barbuda  17.060816 -61.796428
# 4     AI              Anguilla  18.220554 -63.068615
# ..   ...                   ...        ...        ...
# 239   YE                 Yemen  15.552727  48.516388
# 240   YT               Mayotte -12.827500  45.166244
# 241   ZA          South Africa -30.559482  22.937506
# 242   ZM                Zambia -13.133897  27.849332
# 243   ZW              Zimbabwe -19.015438  29.154857
#
# [244 rows x 4 columns]

# %%
len(coordinates)
# Out:
# 244

# %%
arr = []

for i in np.arange(244):
    arr.append(list(coordinates.values[i, :]))

# %%
arr
# Out:
# [['AD', 'Andorra', 42.546245, 1.6015540000000001],
#  ['AE', 'United Arab Emirates', 23.424076, 53.847818000000004],
#  ['AF', 'Afghanistan', 33.93911, 67.709953],
#  ['AG', 'Antigua and Barbuda', 17.060816, -61.796428000000006],
#  ['AI', 'Anguilla', 18.220554, -63.068615],
#  ['AL', 'Albania', 41.153332, 20.168331],
#  ['AM', 'Armenia', 40.069099, 45.038189],
#  ['AN', 'Netherlands Antilles', 12.226078999999999, -69.060087],
#  ['AO', 'Angola', -11.202691999999999, 17.873887],
#  ['AQ', 'Antarctica', -75.250973, -0.071389],
#  ['AR', 'Argentina', -38.416097, -63.616671999999994],
#  ['AS', 'American Samoa', -14.270972, -170.132217],
#  ['AT', 'Austria', 47.516231, 14.550072],
#  ['AU', 'Australia', -25.274398, 133.775136],
#  ['AW', 'Aruba', 12.52111, -69.968338],
#  ['AZ', 'Azerbaijan', 40.143105, 47.576927000000005],
#  ['BA', 'Bosnia and Herzegovina', 43.915886, 17.679076000000002],
#  ['BB', 'Barbados', 13.193887, -59.543198],
# ...

# %%
newArr = {}
for i in arr:
    newArr[i[1]] = { "lat":f"{i[2]}", "lon":f"{i[3]}"}

# %%
newArr
# Out:
# {'Andorra': {'lat': '42.546245', 'lon': '1.6015540000000001'},
#  'United Arab Emirates': {'lat': '23.424076', 'lon': '53.847818000000004'},
#  'Afghanistan': {'lat': '33.93911', 'lon': '67.709953'},
#  'Antigua and Barbuda': {'lat': '17.060816', 'lon': '-61.796428000000006'},
#  'Anguilla': {'lat': '18.220554', 'lon': '-63.068615'},
#  'Albania': {'lat': '41.153332', 'lon': '20.168331'},
#  'Armenia': {'lat': '40.069099', 'lon': '45.038189'},
#  'Netherlands Antilles': {'lat': '12.226078999999999', 'lon': '-69.060087'},
#  'Angola': {'lat': '-11.202691999999999', 'lon': '17.873887'},
#  'Antarctica': {'lat': '-75.250973', 'lon': '-0.071389'},
#  'Argentina': {'lat': '-38.416097', 'lon': '-63.616671999999994'},
#  'American Samoa': {'lat': '-14.270972', 'lon': '-170.132217'},
#  'Austria': {'lat': '47.516231', 'lon': '14.550072'},
#  'Australia': {'lat': '-25.274398', 'lon': '133.775136'},
#  'Aruba': {'lat': '12.52111', 'lon': '-69.968338'},
# ...
